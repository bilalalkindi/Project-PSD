# %% [markdown]
# # IIR VS FIR

# %% [markdown]
# ### Sinyal dan Filter

# %% [markdown]
# Pada bagian sebelumnya, kami memperkenalkan konsep sinyal, spektrum, dan bentuk Z. Selama perjalanan sinyal dari sumber ke penerima, urutan data mengalami perubahan dan transformasi. Transformasi ini terjadi saat sinyal melewati berbagai perangkat komputasi yang melakukan operasi matematika tertentu. Dalam pemrosesan sinyal digital, data melewati rangkaian digital yang disebut filter. Filter digital, mirip dengan filter analog, memiliki karakteristik yang berbeda. Biasanya, karakteristik ini dinyatakan dalam representasi frekuensi - yaitu, karakteristik amplitudo-frekuensi dan fase-frekuensi dari filter. Filter digital terutama digunakan untuk meningkatkan kualitas sinyal - baik untuk mengekstraksi sinyal dari urutan data, atau untuk mengurangi sinyal yang tidak diinginkan - dengan menekan sinyal tertentu dalam urutan sampel yang diterima.

# %% [markdown]
# Saat ini, filter digital digunakan hampir di mana saja di mana pemrosesan sinyal diperlukan. Bahkan operasi matematika dasar (perkalian dan penjumlahan) dapat direpresentasikan sebagai filter digital. Oleh karena itu, semua perangkat di sekitar kita (komputer, telepon, televisi, dll.) mengandung berbagai filter digital. Misalnya, televisi menggunakan filter untuk mengubah tampilan gambar. Penyesuaian kecerahan pada dasarnya adalah proses filtrasi gambar. Filter digital digunakan dalam berbagai tugas pemrosesan sinyal, seperti analisis spektral, pemrosesan data audio dan video, pemrosesan ucapan, dan pemrosesan gerakan. Khusus untuk tugas-tugas DSP, filter adalah sistem matematis yang mengubah bentuk sinyal masukan dalam hal amplitudo, fase, dan frekuensi.

# %% [markdown]
# Keunggulan Filter Digital:

# %% [markdown]
# - Kemampuan untuk mencapai karakteristik yang tidak mungkin diperoleh dengan metode analog, seperti respons frekuensi yang tepat linear.
# - Filter digital lebih stabil terhadap perubahan lingkungan eksternal (suhu, kelembaban, tekanan), sehingga tidak memerlukan kalibrasi yang terus-menerus.
# - Kemudahan dalam mengubah frekuensi pemrosesan sinyal.
# - Tergantung pada kecepatan pemrosesan dan frekuensi sinyal, satu filter dapat memproses data dari beberapa saluran secara bersamaan.
# - Data sebelum dan setelah filter dapat disimpan dalam media penyimpanan apa pun, sementara sinyal analog sulit untuk direkam tanpa konversi ke bentuk digital.
# - Konsumsi daya rendah dan biaya lebih rendah dibandingkan dengan filter analog.
# - Tingkat akurasi yang lebih tinggi dalam perhitungan, karena perangkat digital modern tidak terbatas oleh akurasi perhitungan.
# - Kemudahan dalam merancang filter dengan karakteristik frekuensi yang kompleks.
# - Dalam tugas-tugas biomedis, penggunaan filter analog pada frekuensi yang sangat rendah sulit, berbeda dengan filter digital.

# %% [markdown]
# Kekurangan Filter Digital:

# %% [markdown]
# - Keterbatasan resolusi: Dalam perhitungan pada filter digital dengan resolusi terbatas, terjadi akumulasi noise kuantisasi dan noise pembulatan. Salah satu tugas umum dalam DSP adalah memilih resolusi filter yang sesuai.
# - Keterbatasan kecepatan pemrosesan: Biasanya, filter analog mampu memproses data pada frekuensi yang sangat tinggi, sementara filter digital dibatasi oleh frekuensi sampling.
# - Keterbatasan perangkat keras: Karena sinyal nyata di alam adalah kontinu, ADC (Analog-to-Digital Converter) dan DAC (Digital-to-Analog Converter) digunakan untuk memprosesnya. Kualitas sinyal digital (atau analog) yang dihasilkan juga tergantung pada karakteristik perangkat ini.

# %% [markdown]
# Sinyal dan filter didefinisikan oleh berbagai fungsi tergantung pada cara mereka direpresentasikan

# %% [markdown]
# | Sinyal | Filter |
# | -------- | -------- |
# | Sampel X(n)| Karakteristik Impuls h(n)|
# | Bentuk Z X(z)  | Fungsi Transfer   H(z)|
# | Kepadatan Spektral | Karakteristik Frekuensi|
# | Spektrum Modulus   | Respon Frekuensi   |
# | Spektrum Argumen   | Respon Fase   |

# %% [markdown]
# Impuls Response (Respon Impuls) <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>h</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
# </math> adalah reaksi rangkaian terhadap masukan berupa fungsi Delta Dirac (fungsi δ). Respon ini mencerminkan pengaruh rangkaian terhadap sinyal. Dalam perangkat digital, respon impuls dapat berakhir atau tak terbatas. Oleh karena itu, ada dua kelas filter digital - filter dengan respon impuls berakhir dan filter dengan respon impuls tak berakhir:

# %% [markdown]
# Filter digital dijelaskan oleh persamaan diferensial:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mfrac>
#     <mn>1</mn>
#     <msub>
#       <mi>a</mi>
#       <mn>0</mn>
#     </msub>
#   </mfrac>
#   <mo>.</mo>
#   <mo stretchy="false">(</mo>
#   <munderover>
#     <mo data-mjx-texclass="OP" movablelimits="false">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>k</mi>
#       <mo>=</mo>
#       <mn>0</mn>
#     </mrow>
#     <mrow data-mjx-texclass="ORD">
#       <mi>N</mi>
#     </mrow>
#   </munderover>
#   <msub>
#     <mi>b</mi>
#     <mi>k</mi>
#   </msub>
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
#   <mo>&#x2212;</mo>
#   <munderover>
#     <mo data-mjx-texclass="OP" movablelimits="false">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>k</mi>
#       <mo>=</mo>
#       <mn>1</mn>
#     </mrow>
#     <mrow data-mjx-texclass="ORD">
#       <mi>M</mi>
#     </mrow>
#   </munderover>
#   <msub>
#     <mi>a</mi>
#     <mi>k</mi>
#   </msub>
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
#   <mo stretchy="false">)</mo>
# </math>

# %% [markdown]
# Dalam formula ini, <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
# </math> adalah respons keluaran atau sampel pada keluaran dari filter digital.  <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
# </math> adalah sinyal masukan. <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>a</mi>
#     <mi>k</mi>
#   </msub>
# </math> dan <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>b</mi>
#     <mi>k</mi>
#   </msub>
# </math> adalah faktor pengali (koefisien) dari elemen-elemen digital baik pada masukan maupun keluaran. Faktor-faktor ini juga disebut sebagai koefisien pembilang dan penyebut dari karakteristik transfer filter.

# %% [markdown]
# Karakteristik Transfer filter memiliki bentuk berikut:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>z</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mi>B</mi>
#       <mo stretchy="false">(</mo>
#       <mi>z</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <mrow>
#       <mi>A</mi>
#       <mo stretchy="false">(</mo>
#       <mi>z</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <msub>
#         <mi>b</mi>
#         <mn>0</mn>
#       </msub>
#       <mo>+</mo>
#       <msub>
#         <mi>b</mi>
#         <mn>1</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#       <mo>+</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>+</mo>
#       <msub>
#         <mi>b</mi>
#         <mi>N</mi>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mi>N</mi>
#         </mrow>
#       </msup>
#     </mrow>
#     <mrow>
#       <mn>1</mn>
#       <mo>+</mo>
#       <msub>
#         <mi>a</mi>
#         <mn>1</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#       <mo>+</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>+</mo>
#       <msub>
#         <mi>a</mi>
#         <mi>M</mi>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mi>M</mi>
#         </mrow>
#       </msup>
#     </mrow>
#   </mfrac>
# </math>

# %% [markdown]
# Di mana N dan M adalah jumlah garis tunda untuk sinyal masukan dan keluaran. Secara umum, ini adalah formula untuk filter IIR. Jika penyebutnya sama dengan satu, maka rumus tersebut menjadi sesuai dengan ekspresi untuk filter FIR (filter digital tanpa umpan balik).
#
# Dalam implementasi filter digital, terdapat dua metode yang berbeda: perangkat keras dan perangkat lunak. Filter perangkat keras diimplementasikan pada FPGA atau prosesor sinyal khusus, sedangkan filter perangkat lunak diimplementasikan menggunakan program yang dijalankan oleh prosesor atau mikrokontroler.
#
# Filter dapat bersifat rekursif, di mana sampel keluaran tergantung pada sampel keluaran sebelumnya serta sampel masukan, yang menunjukkan adanya umpan balik dalam skema, atau non-rekursif, di mana sampel keluaran hanya tergantung pada sampel masukan.

# %% [markdown]
# ### Filter IIR dan FIR

# %% [markdown]
# Filter FIR (finite impulse response) adalah filter digital dengan respon impuls yang terbatas. Ini berarti bahwa karakteristik impuls filter ini dibatasi dalam waktu, memiliki sejumlah koefisien yang terhitung, dan mulai dari suatu titik waktu tertentu, responnya menjadi nol. Jika sinyal impuls satu satuan diberikan pada input filter FIR, keluaran filter akan memiliki jumlah sampel yang terbatas. Biasanya, respon frekuensi filter dengan karakteristik impuls yang terbatas adalah linear.
#
# Secara umum, filter FIR diimplementasikan tanpa umpan balik, yang berarti mereka non-rekursif. Namun, dengan menggunakan transformasi matematika, filter ini dapat diubah menjadi bentuk rekursif.

# %% [markdown]
# Persamaan Diferensial Filter FIR:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <munderover>
#     <mo data-mjx-texclass="OP" movablelimits="false">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>k</mi>
#       <mo>&#x2212;</mo>
#       <mn>0</mn>
#     </mrow>
#     <mrow data-mjx-texclass="ORD">
#       <mi>N</mi>
#       <mo>&#x2212;</mo>
#       <mn>1</mn>
#     </mrow>
#   </munderover>
#   <mi>h</mi>
#   <mo stretchy="false">(</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
# </math>

# %% [markdown]
# dimana:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
# </math> - sinyal diskrit output (jumlah dari puls input yang ditimbang)

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
# </math> - sinyal diskrit input (urutan sampel)

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>h</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
# </math>) - koefisien karakteristik impuls filt

# %% [markdown]
# N - panjang (orde) filter.

# %% [markdown]
# Karakteristik Transfer Filter FIR:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>z</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <munderover>
#     <mo data-mjx-texclass="OP" movablelimits="false">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>k</mi>
#       <mo>&#x2212;</mo>
#       <mn>0</mn>
#     </mrow>
#     <mrow data-mjx-texclass="ORD">
#       <mi>N</mi>
#       <mo>&#x2212;</mo>
#       <mn>1</mn>
#     </mrow>
#   </munderover>
#   <mi>h</mi>
#   <mo stretchy="false">(</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
#   <msup>
#     <mi>z</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mo>&#x2212;</mo>
#       <mi>k</mi>
#     </mrow>
#   </msup>
# </math>

# %% [markdown]
# Peringatkan bahwa operasi <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msup>
#     <mi>z</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mo>&#x2212;</mo>
#       <mi>k</mi>
#     </mrow>
#   </msup>
# </math> - merupakan penundaan urutan sebanyak k-sampel.

# %% [markdown]
# Filter IIR (infinite impulse response) adalah filter digital dengan karakteristik impuls yang tidak terbatas dalam waktu, yang berarti memiliki jumlah koefisien yang sangat besar atau bahkan tak terbatas. Filter IIR juga dikenal sebagai filter rekursif karena menggunakan umpan balik dalam implementasinya (sinyal dari output filter melalui elemen penundaan kembali masuk ke filter dan mempengaruhi perubahan di dalamnya). Fungsi transfer filter IIR berbentuk pecahan rasional. Beberapa jenis filter IIR yang terkenal termasuk filter Chebyshev, Butterworth, Kalman, Bessel, dan lain-lain.

# %% [markdown]
# Persamaan diferensial filter IIR:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <munderover>
#     <mo data-mjx-texclass="OP" movablelimits="false">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>k</mi>
#       <mo>=</mo>
#       <mn>0</mn>
#     </mrow>
#     <mrow data-mjx-texclass="ORD">
#       <mi>N</mi>
#     </mrow>
#   </munderover>
#   <msub>
#     <mi>b</mi>
#     <mi>k</mi>
#   </msub>
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
#   <mo>&#x2212;</mo>
#   <munderover>
#     <mo data-mjx-texclass="OP" movablelimits="false">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>k</mi>
#       <mo>=</mo>
#       <mn>1</mn>
#     </mrow>
#     <mrow data-mjx-texclass="ORD">
#       <mi>M</mi>
#     </mrow>
#   </munderover>
#   <msub>
#     <mi>a</mi>
#     <mi>k</mi>
#   </msub>
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>k</mi>
#   <mo stretchy="false">)</mo>
# </math>

# %% [markdown]
# dan

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <msub>
#     <mi>b</mi>
#     <mn>0</mn>
#   </msub>
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo stretchy="false">)</mo>
#   <mo>+</mo>
#   <msub>
#     <mi>b</mi>
#     <mn>1</mn>
#   </msub>
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mn>1</mn>
#   <mo stretchy="false">)</mo>
#   <mo>+</mo>
#   <msub>
#     <mi>b</mi>
#     <mi>M</mi>
#   </msub>
#   <mi>x</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>M</mi>
#   <mo stretchy="false">)</mo>
#   <mo>+</mo>
#   <mo>.</mo>
#   <mo>.</mo>
#   <mo>.</mo>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>a</mi>
#     <mn>1</mn>
#   </msub>
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mn>1</mn>
#   <mo stretchy="false">)</mo>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>a</mi>
#     <mn>2</mn>
#   </msub>
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mn>2</mn>
#   <mo stretchy="false">)</mo>
#   <mo>&#x2212;</mo>
#   <mo>.</mo>
#   <mo>.</mo>
#   <mo>.</mo>
#   <mo>&#x2212;</mo>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>a</mi>
#     <mi>N</mi>
#   </msub>
#   <mi>y</mi>
#   <mo stretchy="false">(</mo>
#   <mi>n</mi>
#   <mo>&#x2212;</mo>
#   <mi>N</mi>
#   <mo stretchy="false">)</mo>
# </math>

# %% [markdown]
# Seperti yang terlihat, sinyal output mempengaruhi dirinya sendiri melalui umpan balik.

# %% [markdown]
# Karakteristik Transfer Filter IIR:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>z</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mi>B</mi>
#       <mo stretchy="false">(</mo>
#       <mi>z</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <mrow>
#       <mi>A</mi>
#       <mo stretchy="false">(</mo>
#       <mi>z</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#   </mfrac>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <msub>
#         <mi>b</mi>
#         <mn>0</mn>
#       </msub>
#       <mo>+</mo>
#       <msub>
#         <mi>b</mi>
#         <mn>1</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#       <mo>+</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>+</mo>
#       <msub>
#         <mi>b</mi>
#         <mi>N</mi>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mi>N</mi>
#         </mrow>
#       </msup>
#     </mrow>
#     <mrow>
#       <mn>1</mn>
#       <mo>+</mo>
#       <msub>
#         <mi>a</mi>
#         <mn>1</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#       <mo>+</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>.</mo>
#       <mo>+</mo>
#       <msub>
#         <mi>a</mi>
#         <mi>M</mi>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mi>M</mi>
#         </mrow>
#       </msup>
#     </mrow>
#   </mfrac>
# </math>

# %% [markdown]
# Berbeda dengan filter FIR, filter IIR tidak selalu stabil. Agar filter digital IIR tetap stabil, semua akar dari fungsi transfernya harus memiliki magnitudo kurang dari satu, yang berarti harus berada di dalam lingkaran satuan di bidang z.

# %% [markdown]
# Orde filter - derajat tertinggi dalam ekspresi fungsi transfer <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>z</mi>
# </math>)

# %% [markdown]
# Fungsi transfer dapat diimplementasikan dengan berbagai skema struktural. Skema struktural yang paling umum adalah skema serial dan paralel. Skema serial biasanya digunakan ketika fungsi transfer filter rekursif dapat diuraikan menjadi produk fungsi transfer orde pertama dan kedua. Sebaliknya, skema paralel digunakan ketika fungsi transfer filter rekursif dapat diuraikan menjadi jumlah fungsi transfer orde pertama dan kedua.

# %% [markdown]
# ## Skema Kanonik dan Skema Langsung

# %% [markdown]
# Struktur skema filter digital dapat direpresentasikan dalam bentuk langsung dan bentuk kanonik. Filter digital dapat diimplementasikan menggunakan tiga elemen digital: pengali, penjumlah, dan blok penundaan. Pengali digunakan untuk mengalikan sampel dengan koefisien <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>a</mi>
#     <mi>k</mi>
#   </msub>
# </math> dan <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>b</mi>
#     <mi>k</mi>
#   </msub>
# </math>, sementara penjumlah menggabungkan hasil yang diperoleh.

# %% [markdown]
# Skema struktural dari filter FIR non-rekursif sesuai dengan persamaan:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Jumlah elemen penunda selalu satu kurang dari jumlah koefisien atau orde filter. Karakteristik impuls filter FIR sesuai dengan kumpulan koefisien dari filter tersebut.
#
# Skema struktural dari filter IIR terlihat lebih kompleks karena adanya umpan balik.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Jumlah elemen penunda pada filter IIR adalah N + M

# %% [markdown]
# Skema struktural dalam bentuk kanonik mengurangi jumlah elemen penunda dengan menggunakan elemen penunda yang bersamaan. Penjumlah masukan menggunakan umpan balik. Penjumlah keluaran menggabungkan hasil. Transformasi dari satu bentuk ke bentuk lainnya cukup mudah dan sederhana.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Pemilihan Filter

# %% [markdown]
# Pemilihan jenis filter sering kali menjadi pertimbangan penting bagi pengembang perangkat digital. Keputusan antara menggunakan filter FIR atau IIR didasarkan pada kriteria berikut:

# %% [markdown]
# - Karakteristik fase filter IIR bersifat non-linear, sedangkan filter FIR dapat memiliki karakteristik fase yang sepenuhnya linear, yang berarti tidak menyebabkan distorsi pada bentuk sinyal.
# - Filter FIR stabil karena diimplementasikan dalam bentuk non-rekursif, sedangkan filter IIR dapat menjadi tidak stabil.
# - Dalam aplikasi nyata, masalah resolusi data (pembulatan, kuantisasi) menjadi kurang signifikan pada perangkat tanpa umpan balik, seperti pada filter FIR.
# - Untuk mencapai respons frekuensi dengan bentuk yang kompleks atau persegi maksimal, filter FIR membutuhkan jumlah koefisien yang signifikan. Filter IIR lebih efisien dalam menangani tugas ini.
# - Filter FIR umumnya tidak memiliki padanan analog.
# - Filter FIR memudahkan perolehan karakteristik yang diinginkan (tingkat penurunan, ketidakrataan di jalur lewat, frekuensi cut-off, dll.).
# - Filter IIR jauh lebih efisien dalam hal jumlah operasi perkalian, penambahan, dan jumlah elemen penundaannya.

# %% [markdown]
# ### Contoh

# %% [markdown]
# Misalkan ada filter yang dijelaskan oleh fungsi transfer berikut:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>z</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <msub>
#         <mi>b</mi>
#         <mn>0</mn>
#       </msub>
#       <mo>+</mo>
#       <msub>
#         <mi>b</mi>
#         <mn>1</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#       <mo>+</mo>
#       <msub>
#         <mi>b</mi>
#         <mn>2</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>2</mn>
#         </mrow>
#       </msup>
#     </mrow>
#     <mrow>
#       <mn>1</mn>
#       <mo>+</mo>
#       <msub>
#         <mi>a</mi>
#         <mn>1</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#       <mo>+</mo>
#       <msub>
#         <mi>a</mi>
#         <mn>2</mn>
#       </msub>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>2</mn>
#         </mrow>
#       </msup>
#     </mrow>
#   </mfrac>
# </math>

# %% [markdown]
# dimana:

# %% [markdown]
# - <math xmlns="http://www.w3.org/1998/Math/MathML"><math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>N</mi>
#   <mo>=</mo>
#   <mn>2</mn>
#   <mn>,</mn>
# </math>
# </math>
#   <mi>M</mi>
#   <mo>=</mo>
#   <mn>2</mn>
# </math>

# %% [markdown]
# - <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>b</mi>
#     <mi>i</mi>
#   </msub>
#   <mo>=</mo>
#   <mrow data-mjx-texclass="ORD">
#     <mn>0.1</mn>
#     <mo>,</mo>
#     <mo>&#x2212;</mo>
#     <mn>0.6</mn>
#     <mo>,</mo>
#     <mn>0.5</mn>
#   </mrow>
# </math>

# %% [markdown]
# - <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>a</mi>
#     <mi>i</mi>
#   </msub>
#   <mo>=</mo>
#   <mrow data-mjx-texclass="ORD">
#     <mn>1</mn>
#     <mo>,</mo>
#     <mn>0.7</mn>
#     <mo>,</mo>
#     <mo>&#x2212;</mo>
#     <mn>0.2</mn>
#   </mrow>
# </math>

# %% [markdown]
# Jumlah persamaan diferensial untuk filter tertentu sama dengan jumlah penjumlah dalam skema. Dengan mengetahui persamaan diferensial ini, kita dapat menentukan karakteristik impuls filter: sinyal impuls satu unit diterapkan ke input (dengan kondisi awal nol).
#
# Kita akan menentukan karakteristik impuls menggunakan Python. Dengan menggunakan fungsi lfilter(b, a, x), proses melewatkan sinyal x melalui filter digital dimodelkan, menggunakan koefisien a dan b dari karakteristik transfer.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import lfilter, freqz, butter, firls, remez, firwin, firwin2, group_delay
from scipy.fftpack import fft, fftshift

FONT_SMALL = 12
FONT_MEDIUM = 14

plt.rc('axes', titlesize=FONT_MEDIUM) 
plt.rc('axes', labelsize=FONT_SMALL)
plt.rc('xtick', labelsize=FONT_SMALL)
plt.rc('ytick', labelsize=FONT_SMALL) 
plt.rc('legend', fontsize=FONT_MEDIUM) 
plt.rc('figure', titlesize=FONT_MEDIUM)

# %matplotlib inline

# %%
N = 128
x = np.zeros(N)
x[0] = 1

b = [0.1, -0.6, 0.5]
a = [1, 0.7, -0.2]

y1 = lfilter(b, a, x)

plt.figure(figsize=(16, 4), dpi=80)
plt.title('Impulse responce')
plt.stem(y1, basefmt='C0')
plt.xlim([-0.5, N-0.5])
plt.grid(True)

# %% [markdown]
# Jika filter stabil, maka nilai-nilai y(n) akan berkurang seiring waktu.
#
# Seperti yang terlihat pada grafik sebelumnya, filter IIR yang dihitung adalah stabil.

# %% [markdown]
# ### Filter Butterworth

# %% [markdown]
# Contoh implementasi filter Butterworth orde 3. Kami akan menunjukkan bagaimana sinyal yang bising melewati filter tersebut:

# %%
# Create input signal
t = 2 * np.pi * np.linspace(-1, 1, 500)
x = np.sin(0.25*t*t)+ 0.95*np.sin(2.0*t)

# Add some white noise
np.random.seed(1)
xn = x + np.random.randn(len(t))

# 3-order lowpass butterworth filter
b, a = butter(3, 0.2)
z = lfilter(b, a, xn)

wn = [0.01, 0.05, 0.1, 0.2]

# Calculate IIR filter
zz = np.zeros((t.size, 4))
for i in range(4):
    b, a = butter(3, wn[i])
    zz[:, i] = lfilter(b, a, xn)

# Plot results
plt.figure(figsize=(16, 8), dpi=80)
for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.plot(t, xn, 'C0--', linewidth=1.5)
    plt.plot(t, zz[:,i], 'C1', linewidth=2.5)
    plt.xlim([-2 * np.pi, 2 * np.pi])
    plt.grid(True)
    plt.legend(('Signal', 'Filtered, wn = {}'.format(wn[i])), loc='lower right')

# %% [markdown]
# ### Filter FIR Rekursif

# %% [markdown]
# Seperti yang disebutkan sebelumnya, filter FIR biasanya dibangun dalam bentuk non-rekursif, namun ada cara untuk mengubah filter menjadi bentuk rekursif.

# %% [markdown]
# Mari kita lihat contoh berikut. Mari kita tulis karakteristik transfer filter:

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mi>H</mi>
#   <mo stretchy="false">(</mo>
#   <mi>z</mi>
#   <mo stretchy="false">)</mo>
#   <mo>=</mo>
#   <mn>1</mn>
#   <mo>+</mo>
#   <msup>
#     <mi>z</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mo>&#x2212;</mo>
#       <mn>1</mn>
#     </mrow>
#   </msup>
#   <mo>+</mo>
#   <msup>
#     <mi>z</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mo>&#x2212;</mo>
#       <mn>2</mn>
#     </mrow>
#   </msup>
#   <mo>+</mo>
#   <msup>
#     <mi>z</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mo>&#x2212;</mo>
#       <mn>3</mn>
#     </mrow>
#   </msup>
# </math>

# %% [markdown]
# Kita akan mengalikan fungsi transfer dengan

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <mfrac>
#     <mrow>
#       <mn>1</mn>
#       <mo>&#x2212;</mo>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#     </mrow>
#     <mrow>
#       <mn>1</mn>
#       <mo>&#x2212;</mo>
#       <msup>
#         <mi>z</mi>
#         <mrow data-mjx-texclass="ORD">
#           <mo>&#x2212;</mo>
#           <mn>1</mn>
#         </mrow>
#       </msup>
#     </mrow>
#   </mfrac>
# </math>

# %% [markdown]
# Skema struktural dari filter tersebut ditunjukkan pada gambar berikut. Ini terdiri dari dua rantai: elemen tanpa umpan balik - yang diferensiasi, dan elemen dengan umpan balik - yang mengintegrasi (penjumlah dengan umpan balik).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mari kita buat ilustrasi bahwa sinyal yang melewati filter FIR rekursif memiliki karakteristik yang serupa.

# %%
N = 40
x = np.zeros(N)
x[0] = 1

M = 16
b = np.ones(M-1)
a = [1]

y1 = lfilter(b, a, x)

b = np.zeros(M)
b[0] = 1
b[M-1] = -1

a = [1, -1]
y2 = lfilter(b, a, x)

np.all(y1 == y2)
# Out:
# True

# %%
plt.figure(figsize=(16, 3), dpi=80)
plt.stem(y2, basefmt='C0')
plt.xlim([-0.5, N-0.5])
plt.xlabel('Samples')
plt.suptitle('Filtered signal')
plt.grid(True)

# %% [markdown]
# Seperti yang terlihat dari grafik, karakteristik impuls filter rekursif adalah vektor satu. Selain itu, panjang vektor sama dengan panjang filter.

# %% [markdown]
# ### Filter FIR Homogen

# %% [markdown]
# Filter FIR homogen tidak memerlukan operasi perkalian, sehingga bekerja dengan cepat dan cocok untuk implementasi di FPGA.
#
# Namun, filter semacam itu memiliki kekurangan, termasuk tingkat penurunan yang tinggi pada sisi gelombang dalam respons frekuensi. Untuk mengatasi ini, filter seringkali dikaskadkan, di mana posisi nol tetap tidak berubah, namun perbandingan antara level dari sisi utama dan sisi gelombang berubah, menyebabkan penurunan relatif dalam level sisi gelombang ketika respons frekuensi dikalikan.
#
# Selain itu, bentuk respons frekuensi filter homogen tidak persegi. Untuk mengubahnya menjadi lebih persegi, filter FIR korektif digunakan, yang dapat menyebabkan peningkatan tingkat sisi gelombang.
#
# Ketika kita membahas tentang decimation dan interpolation dari sinyal, kita akan menggali lebih dalam tentang penggunaan filter ini.
#
# Untuk menemukan karakteristik frekuensi filter, Anda dapat menggunakan fungsi freqz.

# %%
N = 512
f = np.linspace(0, 1, N, endpoint=True)
b = [1, 1, 1]

plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
for i in range(4):
    _, h = freqz(b, N)
    h = np.abs(h)
    plt.plot(f, h/np.max(h))
    plt.xlim([0, 1])
    plt.grid(True)
    b.append(1)
plt.xlabel('Normalized Freq')
plt.title('CIC freq responce')
plt.tight_layout()

# %% [markdown]
# ### Filter FIR dengan Phase Linear

# %% [markdown]
# Salah satu fitur utama dari filter FIR adalah kemampuannya untuk memberikan karakteristik fase linear yang akurat.
#
# Mengapa ini penting? Saat sinyal melewati filter, berbagai transformasi terjadi. Amplitudo dan fase sinyal berubah sesuai dengan karakteristik frekuensi filter. Untuk sinyal yang terdiri dari berbagai frekuensi, menjaga fase sinyal tidak terdistorsi saat melewati proses pemrosesan digital menjadi krusial. Meskipun menjaga amplitudo sinyal seimbang di jalur lintasan umumnya tidak menimbulkan masalah, masalah dapat muncul ketika kita membicarakan tentang karakteristik fase frekuensi.
#
# Untuk mengevaluasi distorsi fase, penting untuk memahami konsep delay fase dan delay grup.
#
# Delay fase merujuk pada jumlah delay yang dialami oleh setiap komponen frekuensi dalam sinyal. Ini dapat dihitung dengan membagi sudut pergeseran fase dengan frekuensi.

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <msub>
#     <mi>T</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>&#x3D5;</mi>
#     </mrow>
#   </msub>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mo>&#x2212;</mo>
#       <mi>&#x3B8;</mi>
#       <mo stretchy="false">(</mo>
#       <mi>&#x3C9;</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <mi>&#x3C9;</mi>
#   </mfrac>
# </math>

# %% [markdown]
# Grup Delay adalah rata-rata penundaan waktu dari seluruh sinyal multiflektrum. Didefinisikan sebagai turunan fase terhadap frekuensi.

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <msub>
#     <mi>T</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>g</mi>
#     </mrow>
#   </msub>
#   <mo>=</mo>
#   <mfrac>
#     <mrow>
#       <mo>&#x2212;</mo>
#       <mi>d</mi>
#       <mi>&#x3B8;</mi>
#       <mo stretchy="false">(</mo>
#       <mi>&#x3C9;</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <mi>&#x3C9;</mi>
#   </mfrac>
# </math>

# %% [markdown]
#
# Dari rumus untuk Grup Delay, kondisi linearitas FCX filter menjadi jelas. Aturannya:
#
# Jika FCX adalah linear, maka Grup Delay setelah diferensiasi sama dengan konstan.
#
# Dengan kata lain, Grup Delay konstan untuk semua komponen frekuensi. Dengan demikian, linearitas karakteristik fase adalah salah satu fitur paling penting dari filter FIR.

# %% [markdown]
# ### Simetri Karakteristik Impuls

# %% [markdown]
# Untuk memastikan linearitas karakteristik fase frekuensi, penting bagi karakteristik impuls atau koefisien filter FIR untuk memenuhi kondisi simetri. Dengan kata lain, filter FIR dengan karakteristik fase frekuensi linear adalah simetris. Terdapat empat jenis filter yang berbeda dalam hal kelipatan N dan jenis simetri:

# %% [markdown]
# - simetri positif, kelipatan genap,
# - simetri negatif, kelipatan genap,
# - simetri positif, kelipatan ganjil,
# - simetri negatif, kelipatan ganjil.

# %% [markdown]
# Sebagai contoh, untuk filter dengan simetri negatif, kita dapat mencapai pergeseran fasa sebesar <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mfrac>
#     <mi>&#x3C0;</mi>
#     <mn>2</mn>
#   </mfrac>
# </math>. Filter semacam itu digunakan untuk merancang diferensiator dan transformasi Hilbert.

# %% [markdown]
# Envelope dari karakteristik impuls filter FIR dibangun berdasarkan hukum <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mfrac>
#     <mrow>
#       <mi>s</mi>
#       <mi>i</mi>
#       <mi>n</mi>
#       <mo stretchy="false">(</mo>
#       <mi>x</mi>
#       <mo stretchy="false">)</mo>
#     </mrow>
#     <mi>x</mi>
#   </mfrac>
# </math> terlepas dari jenis filter (rendah, tinggi, diferensiator, filter pita, atau filter penolak). Untuk menyelesaikan masalah praktis, tidak perlu memikirkan jenis filter yang dipilih.

# %% [markdown]
# ### Desain Filter FIR

# %% [markdown]
# Pengembangan filter FIR digital melalui serangkaian tahapan sebagai berikut:
#
# - Penetapan Spesifikasi: Filter yang diinginkan (LPF, HPF, bandpass, rejector) dan jumlah koefisien N ditentukan bersama dengan karakteristik frekuensi yang diinginkan, toleransi non-linearitas di dalam band-stop dan band-pass, dan lain-lain.
#
# - Perhitungan Koefisien: Koefisien filter yang memenuhi spesifikasi dari langkah sebelumnya dihitung menggunakan metode dan alat yang sesuai.
#
# - Analisis Dampak Akurasi Akhir: Evaluasi dilakukan terhadap pengaruh efek kuantisasi terhadap koefisien filter, data sementara, dan output.
#
# - Implementasi: Pengembangan filter dilakukan dengan menggunakan perangkat keras atau perangkat lunak, baik dalam bahasa pemrograman yang tersedia, berbasis FPGA, atau prosesor sinyal khusus.
#
# Meskipun tahapan pengembangan dapat sedikit bervariasi, esensi dari desain filter FIR digital tetap konsisten.

# %% [markdown]
# ### Spesifikasi Filter

# %% [markdown]
# Pada tahap ini, insinyur berupaya mencapai solusi kompromi untuk menghasilkan filter FIR yang memenuhi kebutuhan dengan parameter-parameter yang telah ditentukan. Ada beberapa parameter yang harus dipertimbangkan, dan seringkali penyesuaian satu parameter memerlukan pengorbanan pada nilai parameter lainnya untuk mencapai tujuan yang diinginkan.

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>p</mi>
#       <mi>a</mi>
#       <mi>s</mi>
#       <mi>s</mi>
#     </mrow>
#   </msub>
# </math> - ketidakseragaman di dalam jalur lulus

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>s</mi>
#       <mi>t</mi>
#       <mi>o</mi>
#       <mi>p</mi>
#     </mrow>
#   </msub>
# </math> - level penurunan di dalam jalur penolakan

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>F</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>p</mi>
#       <mi>a</mi>
#       <mi>s</mi>
#       <mi>s</mi>
#     </mrow>
#   </msub>
# </math> - frekuensi batas jalur lulus

# %% [markdown]
# <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>F</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>s</mi>
#       <mi>t</mi>
#       <mi>o</mi>
#       <mi>p</mi>
#     </mrow>
#   </msub>
# </math> - frekuensi batas jalur penolakan

# %% [markdown]
# N - urutan filter (jumlah koefisien filter).

# %% [markdown]
# Dalam praktiknya, parameter <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>p</mi>
#       <mi>a</mi>
#       <mi>s</mi>
#       <mi>s</mi>
#     </mrow>
#   </msub>
# </math> dan <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>s</mi>
#       <mi>t</mi>
#       <mi>o</mi>
#       <mi>p</mi>
#     </mrow>
#   </msub>
# </math>didefinisikan dalam desibel (dB), sedangkan jarak antara <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>F</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>p</mi>
#       <mi>a</mi>
#       <mi>s</mi>
#       <mi>s</mi>
#     </mrow>
#   </msub>
# </math> dan <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>F</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>s</mi>
#       <mi>t</mi>
#       <mi>o</mi>
#       <mi>p</mi>
#     </mrow>
#   </msub>
# </math> menunjukkan lebar jalur transisi filter. Secara logis, nilai <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>p</mi>
#       <mi>a</mi>
#       <mi>s</mi>
#       <mi>s</mi>
#     </mrow>
#   </msub>
# </math> harus seminim mungkin, <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>s</mi>
#       <mi>t</mi>
#       <mi>o</mi>
#       <mi>p</mi>
#     </mrow>
#   </msub>
# </math> semaksimal mungkin, dan rasio <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mfrac>
#     <msub>
#       <mi>F</mi>
#       <mrow data-mjx-texclass="ORD">
#         <mi>p</mi>
#         <mi>a</mi>
#         <mi>s</mi>
#         <mi>s</mi>
#       </mrow>
#     </msub>
#     <msub>
#       <mi>F</mi>
#       <mrow data-mjx-texclass="ORD">
#         <mi>s</mi>
#         <mi>t</mi>
#         <mi>o</mi>
#         <mi>p</mi>
#       </mrow>
#     </msub>
#   </mfrac>
# </math> idealnya mendekati satu (penampang frekuensi yang ideal berbentuk persegi).

# %% [markdown]
# Jumlah koefisien tidak disertakan dalam spesifikasi filter tanpa alasan. Seperti yang akan ditunjukkan nanti, parameter-parameter karakteristik frekuensi filter bergantung pada urutan filter N dan resolusi koefisien.

# %% [markdown]
# ### Perhitungan Koefisien Filter

# %% [markdown]
# Terdapat berbagai metode untuk menghasilkan koefisien filter, seperti metode pemutaran jendela, sampling frekuensi, dan metode optimal seperti Chebyshev yang menggunakan algoritma Remez. Setiap metode memiliki karakteristiknya sendiri dan menghasilkan hasil yang berbeda. Metode pemutaran jendela, misalnya, dapat menghasilkan fenomena Gibbs yang mengakibatkan ketidakteraturan dalam karakteristik frekuensi filter. Fenomena ini bisa diatasi dengan memberikan toleransi terhadap ketidakteraturan dalam jalur transmisi dan pita penolakan.
#
# Salah satu metode utama untuk menghitung koefisien filter adalah algoritma Parks-McClellan, yang juga dikenal sebagai algoritma Remez yang dimodifikasi. Algoritma ini adalah metode iteratif tak langsung yang mencari nilai-nilai optimal dengan karakteristik Chebyshev filter. Keunikan dari metode ini adalah minimisasi kesalahan dalam jalur transmisi dan pita penolakan dengan pendekatan Chebyshev terhadap karakteristik impuls.
#
# Secara umum, semakin banyak koefisien yang digunakan, semakin sedikit ketidakteraturan dalam karakteristik frekuensi, dan semakin mendekati bentuk persegi dalam jalur transmisi. Meskipun pilihan metode dapat memengaruhi hasil akhir, tujuannya adalah sama, yaitu untuk meminimalkan lonjakan dalam jalur transmisi dan meningkatkan ketepatan karakteristik frekuensi (dengan mempertahankan keadaan linearitas fase).

# %% [markdown]
# ### Analisis Konsekuensi dari Ketepatan Jumlah Bit yang Terbatas

# %% [markdown]
# Kedalaman bit koefisien merupakan faktor penting yang mempengaruhi bentuk karakteristik frekuensi. Pada perangkat logika yang dapat diprogram (PLD) modern, kedalaman bit koefisien dapat dipilih dengan fleksibel, tetapi biasanya berkisar antara 16 hingga 27 bit karena sifat-sifat blok komputasi (DSP48) yang diterapkan.
#
# Untuk filter dengan orde yang tinggi, seringkali diperlukan rentang dinamis yang luas dalam grid bit. Namun, jika rentang ini tidak dapat dicapai, maka akan terjadi kesalahan kuantisasi. Karena resolusi bit koefisien terbatas, karakteristik frekuensi dapat mengalami modifikasi, bahkan menyebabkan distorsi yang signifikan yang memaksa pengorbanan pada parameter spesifikasi frekuensi. Dengan kata lain, resolusi representasi koefisien secara langsung memengaruhi tingkat penurunan maksimum yang dapat dicapai (<math xmlns="http://www.w3.org/1998/Math/MathML">
#   <msub>
#     <mi>A</mi>
#     <mrow data-mjx-texclass="ORD">
#       <mi>s</mi>
#       <mi>t</mi>
#       <mi>o</mi>
#       <mi>p</mi>
#     </mrow>
#   </msub>
# </math>). Oleh karena itu, ketika menggunakan grid bit yang terbatas, terkadang sulit untuk mencapai penekanan yang diinginkan, bahkan dengan menggunakan filter orde yang sangat tinggi.

# %% [markdown]
# ### Implementasi

# %% [markdown]
# Implementasi filter FIR menggunakan pustaka modern dalam berbagai bahasa pemrograman seperti C++, Python, MATLAB, dan lainnya, relatif mudah. Namun, mengimplementasikan filter FIR pada perangkat keras seperti mikrokontroler atau PLD (Programmable Logic Device) adalah tugas yang kompleks dan menantang.
#
# Untuk mengimplementasikan filter FIR sederhana, diperlukan operasi penundaan, perkalian koefisien, dan penjumlahan hasil perkalian. Komponen utama untuk mengimplementasikan filter FIR pada PLD adalah blok DSP (Digital Signal Processor) berbasis bilangan bulat. Dalam blok ini, semua operasi matematika berlangsung, termasuk perkalian sampel masukan dengan koefisien filter, penundaan sinyal masukan, dan penjumlahan data. Blok DSP modern umumnya dilengkapi dengan pre-summing adder, yang memungkinkan operasi penjumlahan untuk filter dengan respons impuls simetris dilakukan dalam blok tersebut. Selain blok DSP, filter memerlukan memori untuk menyimpan koefisien dan mengimplementasikan elemen penundaan. Biasanya, sumber daya ini berlimpah pada PLD.

# %% [markdown]
# ## Pasangan Filter Konvulasi Tak Hingga di Python

# %% [markdown]
# Implementasi perangkat lunak dari filter konvolusi tak hingga melibatkan pencarian koefisien dari karakteristik impuls.
#
# Penghitungan filter konvolusi tak hingga dapat dilakukan dengan menggunakan beberapa fungsi dari paket scipy.signal. Berikut adalah semua metode perancangan filter konvolusi tak hingga dan tinjauan detail untuk setiap metode.

# %% [markdown]
# | Fungsi| Deskripsi |
# | -------- | -------- |
# | firls(numtaps, bands, desired, weight, nyq, fs)| Penghitungan filter FIR menggunakan metode kuadrat terkecil|
# |firwin(numtaps, cutoff, width, window, ...) | Implementasi filter FIR orde-N dengan penerapan fungsi jendela. Frekuensi cutoff ditentukan |
# | firwin2(numtaps, freq, gain, nfreqs, ...)| Penghitungan filter dengan menerapkan fungsi jendela. Sekumpulan frekuensi yang dinormalisasi dan amplitudo pada frekuensi-frekuensi ini ditentukan |
# | remez(numtaps, bands, desired, weight, Hz, ...)| Penghitungan filter optimal menggunakan algoritma Remez |
# | group_delay(system, w, whole, fs)| Fungsi bantuan untuk menghitung penundaan grup. Parameter input - array koefisien a, b |
# | get_window(window, Nx, fftbins=True)| Mengembalikan koefisien fungsi jendela dengan panjang yang diminta |

# %% [markdown]
# ### Perhitungan Filter Konvulasi Tak Hingga dengan Metode Kuadrat Terkecil

# %% [markdown]
# Dengan menggunakan metode kuadrat terkecil, fungsi ini menghitung koefisien filter yang memberikan pendekatan terbaik terhadap karakteristik frekuensi yang diinginkan. Secara matematis, dalam mencari koefisien, integral dari rata-rata kuadrat error yang ditimbang dalam rentang bandwidth akan diminimalkan.
#
# Metode firls mengembalikan koefisien filter FIR. Argumen input dari fungsi ini meliputi:
# - **numtaps**: orde filter,
# - **bands**: urutan monoton tidak menurun dari frekuensi. Semua elemen harus non-negatif dan kurang dari atau sama dengan frekuensi Nyquist, yang ditentukan oleh parameter nyq,
# - **desired**: urutan amplitudo, berisi penguatan dan penurunan yang diinginkan pada nilai frekuensi yang ditentukan dalam bands,
# - **weight**: "bobot" relatif dari bandwidth dan penekanan. Menentukan kompromi kualitas di bandwidth-bandwidth tersebut,
# - **nyq atau fs**: Frekuensi Nyquist. Jika tidak ditentukan, defaultnya adalah satu.

# %% [markdown]
# ## Perhitungan Filter Konvulasi Tak Hingga dengan Algoritma Remez

# %% [markdown]
# Metode remez mengembalikan koefisien filter FIR. Argumen inputnya identik dengan metode sebelumnya:
#
# - **numtaps**: orde filter,
# - **bands**: urutan monoton tidak menurun dari frekuensi. Semua elemen harus non-negatif dan kurang dari atau sama dengan frekuensi Nyquist, yang ditentukan oleh parameter Hz,
# - **desired**: urutan amplitudo, berisi penguatan dan penurunan yang diinginkan pada nilai frekuensi yang ditentukan dalam bands,
# - **weight**: "bobot" relatif dari bandwidth dan penekanan. Menentukan kompromi kualitas di bandwidth-bandwidth tersebut,
# - **Hz atau fs**: Frekuensi Nyquist. Jika tidak ditentukan, defaultnya adalah satu.

# %% [markdown]
# ## Perhitungan Filter Konvulasi Tak Hingga dengan Metode Jendela

# %% [markdown]
# Metode firwin dan firwin2 mengembalikan koefisien filter FIR.

# %% [markdown]
# ### Metode Firwin

# %% [markdown]
# - **numtaps**: urutan filter,
# - **cutoff**: frekuensi cutoff relatif terhadap laju sampel fs,
# - **width**: lebar transisi dari jalur lintasan ke jalur penekanan (jika ditentukan),
# - **window**: fungsi jendela, dapat digunakan bersama metode get_window atau ditetapkan langsung dengan nama jendela,
# - **fs**: laju sampel atau frekuensi Nyquist, dengan default nilai satu jika tidak ditentukan.

# %% [markdown]
# ### Metode Firwin 2

# %% [markdown]
# - **numtaps**: urutan filter,
# - **freq**: urutan frekuensi monotonik tak menurun. Semua elemen harus non-negatif dan tidak melebihi frekuensi Nyquist yang ditentukan oleh parameter fs,
# - **gain**: urutan amplitudo yang mencakup penguatan dan redaman yang diinginkan pada nilai frekuensi yang ditentukan dalam freq,
# - **window**: fungsi jendela, dapat digunakan bersama metode get_window atau ditetapkan langsung dengan nama jendela,
# - **fs**: laju sampel atau frekuensi Nyquist, dengan default nilai satu jika tidak ditentukan.

# %% [markdown]
# ### Fungsi Jendela

# %% [markdown]
# Bab khusus membahas fungsi jendela dan karakteristiknya, namun beberapa fungsi jendela yang paling umum digunakan dalam praktik meliputi: Kaiser, Gauss, Blackman-Harris, jendela dengan puncak datar, Hamming, Hann, dan lain-lain.
#
# Untuk memilih fungsi jendela, metode get_window digunakan. Argumen masukan meliputi nama jendela dan panjang karakteristik impuls.
#
# Fungsi ini mengembalikan array satu dimensi koefisien - nilai karakteristik impuls. Koefisien ini digunakan dalam operasi konvolusi untuk membentuk karakteristik impuls filter tersebut.

# %% [markdown]
# ### Gelombang Grup

# %% [markdown]
# Ini adalah fungsi bantuan untuk menghitung penundaan grup filter digital. Parameter masukan - larik koefisien a, b. Metode mengembalikan kumpulan frekuensi dan larik penundaan grup yang sesuai untuk frekuensi tersebut.

# %% [markdown]
# ### Contoh

# %% [markdown]
# Contoh pertama - menggunakan fungsi firwin2. Mari tentukan larik frekuensi yang dinormalisasi dari 0 hingga 1. Tentukan penguatan pada frekuensi yang dipilih, serta urutan filter. Mari kita buat karakteristik impuls.

# %%
N = 100
lst_freqs = np.linspace(0, 1, N)

lst_gain = np.zeros(N)
lst_gain[0:20] = 1

NFIR = 64
taps = firwin2(NFIR, lst_freqs, lst_gain)

plt.figure(figsize=(16, 4), dpi=100)
plt.title('Impulse responce')
plt.stem(taps, basefmt='C0')
plt.xlim([0, NFIR-1])
plt.xlabel('Samples')
plt.grid(True)

# %% [markdown]
# Mari kita buat karakteristik amplitudo-frekuensi (AF) dari filter pita dan filter turun rendah menggunakan tiga metode: firls(), remez(), dan firwin2().

# %%
fs = 10
N = 117
desired = (0, 0, 1, 1, 0, 0)
bands = (0, 1, 2, 4, 4.5, 5)

fir_firls = firls(N, bands, desired, fs=fs)
fir_remez = remez(N, bands, desired[::2], fs=fs)
fir_firwin2 = firwin2(N, bands, desired, fs=fs)

plt.figure(figsize=(16, 5))
plt.title('Frequency responce')
for fir in (fir_firls, fir_remez, fir_firwin2):
    freq, resp = freqz(fir)
    resp = np.abs(resp)
    resp /= np.max(resp) + 10**(-15)
    plt.plot(freq, 20*np.log10(resp))
plt.xlim([0, np.pi])
plt.ylim([-180, 5])
plt.legend(['firls', 'remez', 'firwin2'], loc ='upper left')
plt.grid(True)

# %% [markdown]
# ### Kaiser FIR Filter

# %% [markdown]
# Mari kita lihat bagaimana sinyal harmonik yang berisik melewati filter FIR. Kita akan menambahkan beberapa sinyal harmonik frekuensi tinggi dengan amplitudo yang berbeda ke dalam sinyal ini.
#
# Seperti yang terlihat, sinyal berisik sulit untuk dianalisis dalam domain waktu. Namun, dengan melewatkannya melalui filter FIR dengan frekuensi cutoff yang sudah ditentukan, kita dapat memisahkan sinyal yang diinginkan dari gangguan.
#
# Perlu dicatat bahwa semua sinyal dan noise yang masuk ke dalam jalur pass filter akan tetap ada dan akan mempengaruhi kualitas sinyal keluaran.

# %%
N = 1024
t = np.linspace(0, 1, N, endpoint=True)
x = 3*np.cos(2*np.pi*20*t) + 210*np.sin(2*np.pi*117*t) + 100*np.sin(2*np.pi*184*t) + 380*np.sin(2*np.pi*281*t)

np.random.seed(1)
xn = x + 5*np.random.randn(N)

taps = 160
h = firwin(taps, 0.1, window=('kaiser', 9))
y = lfilter(h, 1, xn)

lst_sig = [xn, h, y]

sig_titles = ['Noisy signal', 'FIR impulse responce', 'Filtered signal']
fft_titles = ['Input spectrum', 'FIR filter', 'Result']


plt.figure(figsize=(16, 10))
for i in range(3):
    clc_fft = np.abs(fft(lst_sig[i], N)) 
    clc_fft = 20*np.log10(10e-11+clc_fft/np.max(clc_fft))
    
    plt.subplot(3, 2, 2*i+1)
    plt.plot(lst_sig[i], color='C'+str(i))
    plt.title(sig_titles[i])
    if (i == 2):
        plt.ylim([-5, 5])
        plt.xlim([taps, lst_sig[i].size//2-1])
    else:
        plt.xlim([0, lst_sig[i].size-1])
    plt.grid(True)
    
    plt.subplot(3, 2, 2*(i+1))
    plt.plot(clc_fft, color='C'+str(i))
    plt.title(fft_titles[i])
    plt.xlim([0, N//2-1])
    plt.grid(True)
plt.tight_layout()

# %% [markdown]
# Pada gambar di atas, terlihat bahwa sinyal keluaran yang difilter dengan sedikit distorsi menyerupai sinyal harmonik yang diinginkan. Namun, perlu dicatat bahwa mencapai bentuk gelombang harmonik yang ideal melalui filter FIR atau IIR tidaklah mungkin, karena fungsi utama filter adalah untuk memotong komponen spektral yang tidak diinginkan. Untuk meningkatkan kualitas sinyal yang difilter, metode pemrosesan sinyal digital lainnya, seperti spektral dan korelasi, dapat digunakan.
#
# Ini mengakhiri bagian yang membahas tentang filtrasi digital. Bagian-bagian berikutnya akan menjelaskan secara rinci tentang fungsi jendela, tugas pemrosesan sinyal multi-kecepatan - seperti decimasi dan interpolasi, perhitungan filter korektor, dan lain sebagainya.
